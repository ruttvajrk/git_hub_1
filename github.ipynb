# %%
n1=eval(input("please enter a no"))
n2=eval(input("please enter a no"))
n3=eval(input("please enter a no"))

if n1>n2 and n1>n3:
    print(f"{n1} is a largest no")
elif n2>n1 and n2>n3:
    print(f"{n2} is a largest no")
else:
    print(f"{n3} is a largest no")
